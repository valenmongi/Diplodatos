# %% [markdown]
# # 1° Práctico Análisis Exploratorio y Curación de Datos

# %%
import pandas as pd
import seaborn
import matplotlib as plt
import numpy as np
import plotly.plotly as py
import plotly.figure_factory as ff

# %% [markdown]
# **Ejercicio Tablas PESO**

# %%
weight = pd.read_csv('wtageinf.csv')

# %%
weight.head(5)
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
# 2    1     1.5  1.068796  4.879525  0.136479  3.614688  3.774849  4.020561
# 3    1     2.5  0.695974  5.672889  0.129678  4.342341  4.503255  4.754479
# 4    1     3.5  0.419815  6.391392  0.124717  4.992898  5.157412  5.416803
#
#         P25       P50       P75       P90       P95       P97
# 0  3.150611  3.530203  3.879077  4.172493  4.340293  4.446488
# 1  3.597396  4.003106  4.387423  4.718161  4.910130  5.032625
# 2  4.428873  4.879525  5.327328  5.728153  5.967102  6.121929
# 3  5.183378  5.672889  6.175598  6.638979  6.921119  7.106250
# 4  5.866806  6.391392  6.942217  7.460702  7.781401  7.993878

# %%
#Tabla peso para Hombres
filtrado_1= weight[weight.Sex==1]
filtrado_1.plot(x='Agemos', y=['P3','P5','P10','P25','P50','P75','P90','P95','P97'])
plt.pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.pyplot.title("Tablas de Peso por percentil - Hombres")
seaborn.despine()

# %%
#Tabla peso para Mujeres
filtrado_0= weight[weight.Sex==2]
filtrado_0.plot(x='Agemos', y=['P3','P5','P10','P25','P50','P75','P90','P95','P97'])
plt.pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.pyplot.title("Tablas de Peso por percentil - Mujeres")
seaborn.despine()

# %% [markdown]
# **Ejercicio Paso Fronterizos**

# %%
import chardet
import string

string.ascii_letters + string.digits
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %%
 pasos = pd.read_json('pasos.json', encoding="utf-8")

# %%
pasos = pd.DataFrame(pasos)

# %%
pasos_1 = pasos.set_index('name')

# %%
pasos_2 = pasos_1[pasos_1.index.duplicated(keep=False)]
pasos_2
# Out:
#                                                                       location  \
# name
# AERO RIO GALLEGOS                                   [-51.6117879, -69.3085038]
# AERO RIO GALLEGOS                                   [-51.6117879, -69.3085038]
# ING. PALLAVICINI - IBAÑEZ                           [-46.2752267, -71.7270022]
# ING. PALLAVICINI - IBAÑEZ                           [-46.2752267, -71.7270022]
# AERO COMODORO RIVADAVIA                             [-45.7894354, -67.4696871]
# AERO COMODORO RIVADAVIA                             [-45.7894354, -67.4696871]
# AERO NEUQUEN                                         [-38.9521333, -68.142673]
# AERO NEUQUEN                                         [-38.9521333, -68.142673]
# AERO MAR DEL PLATA                                  [-37.9341161, -57.5745361]
# CRISTO REDENTOR (LIBERTADORES)                       [-32.825277, -70.0729456]
# CRISTO REDENTOR (LIBERTADORES)                       [-32.825277, -70.0729456]
# ...

# %%
pasos_3 = pasos.drop_duplicates('name')

# %%
dataset = pd.DataFrame(pasos_3, columns=['name', 'provincia', 'location'])

# %%
dataset_24 = dataset.replace(['Cordoba','NEUQUEN'], ['Córdoba','Neuquen'])

# %%
plt.pyplot.figure(figsize=(25,8))
seaborn.countplot(x='provincia', data=dataset_24, order = dataset_24['provincia'].value_counts().index)
plt.pyplot.title("Cantidad de pasos fronterizos por provincia")
seaborn.despine()

# %%
dataset_1 = pd.DataFrame(dataset_24.groupby('provincia').size())
dataset_1.rename(columns={0:'Cantidad pasos fronterizos por provincia'}, inplace=True)

# %%
seaborn.distplot(dataset_1)
